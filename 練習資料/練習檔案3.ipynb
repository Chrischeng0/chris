# %%
######你是阿神######
import random as rm
import pyinputplus as pyip
金=0
def butter_room():
    input('find the butter 開始')
    while(True):
        廚房=1
        書房=2
        客廳=3
        寢室=4
        廁所=5
        按鈕=rm.randint(1,5)
        按鈕地=rm.randint(1,10)
        op=int(input('1廚房 2書房 3客廳 4寢室 5廁所 '))
        if op==1:
            kitchen=int(input('1櫥櫃 2梳理台 0回大門'))
            if kitchen==1:
                if kitchen==按鈕地:
                    input('......')
                    input('我找到按鈕了!')
                    input('羽毛:蝦?這麼快')
                    break
                else:
                    input('這裡沒有按鈕')
                    kitchen=int(input('1櫥櫃 2梳理台 0回大門'))
            elif kitchen==2:
                if kitchen==按鈕地:
                    input('......')
                    input('我找到按鈕了!')
                    input('羽毛:蝦?這麼快')
                    break
                else:
                    input('這裡沒有按鈕')
                    kitchen=int(input('1櫥櫃 2梳理台 0回大門'))
        elif op==2:
                bookroom=int(input('3書櫃 4書桌 0回大門'))
                if bookroom==3:
                    if bookroom==按鈕地:
                        input('......')
                        input('我找到按鈕了!')
                        input('羽毛:蝦?這麼快')
                        break
                    else:
                        input('這裡沒有按鈕')
                        
                elif bookroom==4:
                    if bookroom==按鈕地:
                        input('......')
                        input('我找到按鈕了!')
                        input('羽毛:蝦?這麼快')
                        break
                    else:
                        input('這裡沒有按鈕')
                        
                else:
                    input('你回到了大門')
                    break
        elif op==3:
                livingroom=int(input('5沙發 6餐桌 0回大門'))
                if livingroom==5:
                    if livingroom==按鈕地:
                        input('......')
                        input('我找到按鈕了!')
                        input('羽毛:蝦?這麼快')
                        break
                    else:
                        input('這裡沒有按鈕')
                        
                elif livingroom==6:
                    if livingroom==按鈕地:
                        input('......')
                        input('我找到按鈕了!')
                        input('羽毛:蝦?這麼快')
                        break
                    else:
                        input('這裡沒有按鈕')
                        
                else:
                    input('你回到了大門')
                    break
        elif op==4:
                bedroom=int(input('5床 6玩具箱 0回大門'))
                if bedroom==5:
                    if bedroom==按鈕地:
                        input('......')
                        input('我找到按鈕了!')
                        input('羽毛:蝦?這麼快')
                        break
                    else:
                        input('這裡沒有按鈕')
                        
                elif bedroom==6:
                    if bedroom==按鈕地:
                        input('......')
                        input('我找到按鈕了!')
                        input('羽毛:蝦?這麼快')
                        break
                    else:
                        input('這裡沒有按鈕')
                        
                else:
                    input('你回到了大門')
                    break
        else:
                toilet=int(input('5馬桶 6浴缸 0回大門'))
                if toilet==5:
                    if toilet==按鈕地:
                        input('......')
                        input('我找到按鈕了!')
                        input('羽毛:蝦?這麼快')
                        break
                    else:
                        input('這裡沒有按鈕')
                        
                elif toilet==6:
                    if toilet==按鈕地:
                        input('......')
                        input('我找到按鈕了!')
                        input('羽毛:蝦?這麼快')
                        break
                    else:
                        input('這裡沒有按鈕')
                        
                else:
                    input('你回到了大門')
                    break
def p_vs_p():

    input('p_vs_p 開始')
    對手血=10
    阿神血=10
    對手攻擊力=1
    阿神攻擊力=1
    對手=rm.randint(1 ,3)
    if 對手==1:
        input('對手是羽毛')
    elif 對手==2:
        input('對手是李聽')
    else: 
        input('對手是雪兔')
    while(True):
        
        對手動作=rm.randint(1 ,4)
        打=int(input('1打 2防禦 3回復 4集氣'))
        if 打==1:
            if 對手動作==1:
                對手血-=阿神攻擊力
                阿神血-=對手攻擊力
                input(f'對手打了你,你血剩{阿神血},對手血剩{對手血}')
            elif 對手動作==2:
                input(f'對手防禦,你血剩{阿神血},對手血剩{對手血}')
            elif 對手動作==3:
                對手血-=阿神攻擊力
                對手血+=1
                input(f'對手回復,你血剩{阿神血},對手血剩{對手血}')  
            else: 
                對手血-=阿神攻擊力
                對手攻擊力+=1
                input(f'對手集氣,你血剩{阿神血},對手血剩{對手血}')  
        elif 打==2:
            if 對手動作==1:
                input(f'對手攻擊,你血剩{阿神血},對手血剩{對手血}')
            elif 對手動作==2:
                input(f'對手防禦,你血剩{阿神血},對手血剩{對手血}')
            elif 對手動作==3:
                對手血+=1
                input(f'對手回復,你血剩{阿神血},對手血剩{對手血}')  
            else: 
                對手攻擊力+=1
                input(f'對手集氣,你血剩{阿神血},對手血剩{對手血}') 
        elif 打==3:
            if 對手動作==1:
                阿神血-=對手攻擊力
                阿神血+=1
                input(f'對手攻擊,你血剩{阿神血},對手血剩{對手血}')
            elif 對手動作==2:
                阿神血+=1
                input(f'對手防禦,你血剩{阿神血},對手血剩{對手血}')
            elif 對手動作==3:
                阿神血+=1
                對手血+=1
                input(f'對手回復,你血剩{阿神血},對手血剩{對手血}')  
            else: 
                阿神血+=1
                對手攻擊力+=1
                input(f'對手集氣,你血剩{阿神血},對手血剩{對手血}') 
        else:
            if 對手動作==1:
                阿神攻擊力+=0.5
                阿神血-=對手攻擊力
                input(f'對手攻擊,你血剩{阿神血},對手血剩{對手血}')
            elif 對手動作==2:
                阿神攻擊力+=0.5
                input(f'對手防禦,你血剩{阿神血},對手血剩{對手血}')
            elif 對手動作==3:
                阿神攻擊力+=0.5
                對手血+=1
                input(f'對手回復,你血剩{阿神血},對手血剩{對手血}')  
            else: 
                阿神攻擊力+=0.5
                對手攻擊力+=1
                input(f'對手集氣,你血剩{阿神血},對手血剩{對手血}') 
        if 阿神血<=0 and 對手血>0:
            input('你死了,對手贏了')  
            break  
        elif 阿神血<=0 and 對手血<0:
            input('平手')  
            break
        elif 阿神血>=0 and 對手血<0:
            input('對手死了,你贏了')
            break
        else:
            continue
##阿神散財大挑戰
def 貪心往下挖():
    input('貪心往下挖 開始!')
    input('有四個孔,四個孔都是直直往下的,每個孔都有隨機個鑽石,挖到一個鑽石就是50塊錢,最深處有岩漿,隨時可以喊停')
    孔=input('1=一孔 2=二孔 3=三孔 4=四孔')
    if 孔==1:
        while(True):
            一孔=rm.randint(1,20)
            一=一孔
            挖=input('1挖 2停')
            if 挖=='1':
                一-=1
                if 一<=0:
                    input('你太貪心了,你死了')
                    金=0
                    break
                else:
                    金=金+50
                    input(f'你有{金}塊錢')
                    continue
            else:
                input(f'你有{金}塊錢')
                break
    elif 孔==2:
        while(True):
            二孔=rm.randint(1,20)
            二=二孔
            挖=input('1挖 2停')
            if 挖=='1':
                二-=1
                if 二<=0:
                    input('你太貪心了,你死了')
                    金=0
                    break
                else:
                    金=金+50
                    input(f'你有{金}塊錢')
                    continue
            else:
                input(f'你有{金}塊錢')
                break
    elif 孔==3:
        while(True):
            三孔=rm.randint(1,20)
            三=三孔
            挖=input('1挖 2停')
            if 挖=='1':
                三-=1
                if 三<=0:
                    input('你太貪心了,你死了')
                    金=0
                    break
                else:
                    金=金+50
                    input(f'你有{金}塊錢')
                    continue
            else:
                input(f'你有{金}塊錢')
                break
    else:
        while(True):
            四孔=rm.randint(1,20)
            四=四孔
            挖=input('1挖 2停')
            if 挖=='1':
                四-=1
                if 四<=0:
                    input('你太貪心了,你死了')
                    金=0
                    break
                else:
                    金=金+50
                    input(f'你有{金}塊錢')
                    continue
            else:
                input(f'你有{金}塊錢')
                break
    

    

input('哈囉,大家好,我是阿神')
input('我們今天 要來玩麥塊')
input('我們今天 要來玩麥塊 小遊戲比賽 哈囉哈囉')
input('哈囉大家好,我是羽毛')
input('挖洗李聽啦!看啥')
input('嗨嗨 我是雪兔')
input('我們今天吼,要玩一~頭拉庫的小遊戲吼')
input('來看看我和羽毛跟雪兔和李聽誰比較強啦吼')
input('有find the butter、p vs p、生存和速疊吼')
input('要先哪一個?')


while(True):
    oo=input('1:find the butter 2:p vs p 3:阿神散財大挑戰 4:速疊大賽')
    if oo=='1':
        butter_room()
    elif oo=='2':
        p_vs_p()
    elif oo=='3':
        貪心往下挖()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 315
#     313     p_vs_p()
#     314 elif oo=='3':
# --> 315     貪心往下挖()
#
# Cell In[2], line 286, in 貪心往下挖()
#     284     break
#     285 else:
# --> 286     金=金+50
#     287     input(f'你有{金}塊錢')
#     288     continue
#
# UnboundLocalError: local variable '金' referenced before assignment
