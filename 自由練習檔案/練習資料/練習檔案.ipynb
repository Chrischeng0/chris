# %%
is_furry = input("請問動物有毛嗎?(y,n)")
is_small = input("請問動物是小的嗎?(y,n)")

if is_furry == "y":
   if is_small=="y":
      print('它是貓')

if is_furry == "y":
   if is_small=="n":
      print('它是熊')

if is_furry == "n":
   if is_small=="y":
      print('它是小蜥蜴')

if is_furry == "n":
   if is_small=="n":
      print('它是人類或沒有毛的熊')
# Out:
# 它是熊

# %%
Q1 = input('請問家裡有幾個人?(1-5)')
Q2 = input('請問家裡的笨蛋是誰?(陳品__)')
Q3 = input('請問妹妹會翻身嗎?(y,n)')

if Q1 == "5":
    if Q2 == "浩":
        if Q3 == "y":
            print('你的智商很高嘛!')

if Q1 != "5":
    if Q2 == "浩":
        if Q3 == "y":
            print('你的智商很普通嘛!')

if Q1 != "5":
    if Q2 != "浩":
        if Q3 == "y":
            print('你的智商挺低的嘛!')
            
if Q1 == "5":
    if Q2 == "浩":
        if Q3 != "y":
            print('你的智商很普通嘛!')

if Q1 == "5":
    if Q2 != "浩":
        if Q3 == "y":
            print('你的智商很普通嘛!')
            
if Q1 == "5":
    if Q2 != "浩":
        if Q3 != "y":
            print('你的智商挺低的嘛!')

if Q1 != "5":
    if Q2 == "浩":
        if Q3 != "y":
            print('你的智商挺低的嘛!')

if Q1 != "5":
    if Q2 != "浩":
        if Q3 != "y":
            print('甚麼嘛!你根本沒智商丫!')
# Out:
# 你的智商很普通嘛!

# %%
a=input('你在一個遊戲中')
b=input('你遇到了一些武器')
c=input('請你選擇')
d=input('劍或盾')
e=input('弓或盔甲(背後)')
f=input('大劍或頭盔')
if d=="盾":
    if e=="盔甲":
         if f=="大劍":
            print('前面出現了一隻大怪物，你打贏了')
if d!="盾":
    if e!="盔甲":
         if f=="大劍":
            print('前面出現了一隻大怪物，你瞬間被殺死了')
if d!="盾":
    if e=="盔甲":
         if f!="大劍":
            print('前面出現了一隻大怪物，你瞬間被殺死了')
if d=="盾":
    if e!="盔甲":
         if f!="大劍":
            print('前面出現了一隻大怪物，你瞬間被殺死了')
if d!="盾":
    if e=="盔甲":
         if f=="大劍":
            print('前面出現了一隻大怪物，你的心臟被刺穿了')
if d=="盾":
    if e!="盔甲":
         if f=="大劍":
            print('前面出現了隻大怪物，怪物繞到你背後，你被腰斬了')
if d=="盾":
    if e=="盔甲":
         if f!="大劍":
            print('前面出現了一隻大怪物，你逃了')
# Out:
# 前面出現了一隻大怪物，你打贏了

# %%
import random

s=(random.randint(2, 3))
s1=(random.randint(2, 5))
s2=(random.randint(3, 4))
s3=(random.randint(3, 6))
a=input('歡迎來到魔鬼訓練營')
b=input('你遇到了.......烏龜!')
c=input('1斬 2劈')

if c=='1':
    d=input(f'烏烏龜血剩{7-s}滴血')
    d1=7-s
    e=input('1斬 2劈')
    if e=='1':
        e1=input(f'烏烏龜血剩{d1-s}滴血') 
    else:
        r1=7-s1
        r3=input(f'烏烏龜血剩{r1-s1}滴血')
        re=r1-s1
    if re <= 0:
         rrrrr=input('你打贏了烏龜')
         L1=input('你升級了')
         rr=input('算你運氣好，可是還沒結束呢!')
         rrr=input('你遇到了一隻蝙蝠')
         rrrr=input('1斬 2劈')
         if rrrr=='1':
             rr1=10-s2
             rr2=input(f'蝙蝠血血剩{10-s2}滴血')
         else:
             rr11=10-s3
             rr3=input(f'蝙蝠血血剩{10-s3}滴血')
             rr4=input('1斬 2劈')
             if rr4=='1':
                    rr5=10-s2
                    rr6=input(f'蝙蝠血血剩{rr5-s2}滴血')
             else:
                  rr11=10-s3
                  rr3=input(f'蝙蝠血血剩{rr11-s3}滴血')
                  rr44=rr11-s3
             if rr44<=0:
                 r19=input('你打贏了蝙蝠')
             else:
                 input('哼!兩下還打不死蝙蝠')
                      

    else:
         r8=input('哼!兩下還打不死烏龜')     
else:
    r1=7-s1
    r=input(f'烏烏龜血剩{7-s1}滴血')
    d1=7-s
    e=input('1斬 2劈')
    if e=='1':
        e1=input(f'烏烏龜血剩{d1-s}滴血') 
    else:
        r1=7-s1
        r3=input(f'烏烏龜血剩{r1-s1}滴血')
        r4=r1-s1
if r4 <= 0:
    r5=input('你打贏了烏龜')
else:
    r6=input('哼!兩下還打不死烏龜')
if r4 <= 0:
    r7=input('你打贏了烏龜')
    L1=input('你升級了')
    rr=input('算你運氣好，可是還沒結束呢!')
    rrr=input('你遇到了一隻蝙蝠')
    rrrr=input('1斬 2劈')
    if rrrr=='1':
        r1r1=10-s2
        r2r2=input(f'蝙蝠血剩{10-s2}滴血')
    else:
         r1r11=10-s3
         r3r3=input(f'蝙蝠血剩{10-s3}滴血')
         r4r4=input('1斬 2劈')
         if r4r4=='1':
             r111r=r1r11-s2
             r2r1=input(f'蝙蝠血剩{r1r11-s2}滴血')
         else:
             r111r=r1r11-s3
             r222r=input(f'蝙蝙蝠血剩{r1r11-s3}滴血')
    if r111r<=0:
        r19=input('你打贏了蝙蝠')
    else:
        input('哼!兩下還打不死蝙蝠')

# %%
import random
computer=(random.randint(1, 5))
player=input('please write the number(1---5)')
if player==computer:
    input(f'{computer}={player}')
    input('You win')
else:
    input(f'{computer}!={player}')
    input('You lost')

# %%
import random
hit=(random.randint(1, 5))
a=input('你來到了運動會')
b=input('第一個項目是..................桌球!')
c=input('對方發球，打來(平球)')
d=input('1拉球 2切球')
if d=='1':
    e=input('對方打削球，打來(下旋球)')
    f=input('1拉球 2切球')
    if f=='2':
        g=input('對方拉球，打來(上旋球)')
        h=input('1拉球 2切球')
        if h=='1':
            i=input('你打贏了桌球選手')
            j=input('第二場')
            K=input('對方發球，打來(切球)')            
            l=input('1殺球 2削球')
            if l=='2':
                 m=input('對方撈球，打來(左上旋球)')
                 n=input('1拉球 2切球')
                 if n=='1':
                     o=input('1往左打 2往右打')
                     if o=='1':
                          p=input('對方救球，打來(高球)')
                          q=input('1轟球 2切球 3削球 4殺球 5撈球 6搶拍')
                          if q=='4':
                              r=input('你打贏了桌球選手')
                              s=input('桌球選手給你福袋')
                              t=input('裡面有:終界珍珠')
                              u=input('第二個項目是..................棒球!')
                              v=input('我方進攻')
                              w=input('敵方投球')
                              x=input('1=打擊')
                              if x=='1':
                                  if hit!='3':
                                      y=input('你上了一壘')
                                      z=input('1=打擊')
                                      if z=='1':
                                          if hit!='3':
                                              y1=input('你上了二壘')
                                              z1=input('1=打擊')
                                              if z1=='1':
                                                  if hit!=3:
                                                     y2=input('你上了三壘')
                                                     z2=input('1=打擊') 
                                                     if z2=='1':
                                                         if hit!='3':
                                                             y3=input('你回了本壘')
                                                             z3=input('你贏了')


                                  if hit==3:
                                      y1=input('三震出局')
                                      sss=input('你輸了')

# %%
import random
hit=(random.randint(1, 5))
hit1=(random.randint(1, 5))
hit2=(random.randint(1, 5))
hit3=(random.randint(1, 5))
hit4=(random.randint(1, 5))
hit5=(random.randint(1, 5))
hit6=(random.randint(1, 5))
hit7=(random.randint(1, 4))
hit8=(random.randint(1, 4))
hit9=(random.randint(1, 4))
hit10=(random.randint(1, 4))
hit11=(random.randint(1, 4))
hit12=(random.randint(1, 4))
u=input('第二個項目是..............棒球')                             
v=input('我方進攻')
w=input('敵方投球')
x=input('1=打擊')
if x=='1':
    if hit!=3:
        y=input(f'{hit}你上了一壘')
        z=input('1=打擊')
        if z=='1':
            if hit4!=3:
                    y1=input(f'{hit4}你上了二壘')
                    z1=input('1=打擊')
                    if z1=='1':
                            if hit2!=3:
                                    y2=input(f'{hit2}你上了三壘')
                                    z2=input('1=打擊') 
                                    if z2=='1':
                                            if hit1!=3:
                                                    y3=input(f'{hit1}你回了本壘')
                                                    z3=input('你贏了')
                                                    aa=input('第二局')
                                                    bb=input('我方防守')
                                                    cc=input('敵方進攻')
                                                    dd=input('1變速球')
                                                    if dd=='1':
                                                            if hit7!=2:
                                                                    ee=input('一陣出局')
                                                                    ff=input('1變速球')
                                                                    if ff=='1':
                                                                         if hit8!=2:
                                                                                 gg=input('二陣出局')
                                                                                 hh=input('1變速球')
                                                                                 if hh=='1':
                                                                                     if hit9!=2:
                                                                                            ii=input('三陣出局')
                                                                                            jj=input('你贏了')
                                                                                     if hit9==2:
                                                                                          lost=input('敵方打出全壘打')  
                                                                                          lllost=input('你輸了')
                                                                         if hit8==2:
                                                                                          lost=input('敵方打出全壘打')  
                                                                                          lllost=input('你輸了')
                                                            if hit7==2:
                                                                                          lost=input('敵方打出全壘打')  
                                                                                          lllost=input('你輸了')
                                            if hit1==3:
                                                    y1=input('三震出局')
                                                    sss=input('你輸了')
                            if hit2==3:
                                      y1=input('三震出局')
                                      sss=input('你輸了')
            if hit4==3:
                      y1=input('三震出局')
                      sss=input('你輸了')
    if hit6==3:
              y1=input('三震出局')
              sss=input('你輸了')

# %%
import random
hit=(random.randint(1, 5))
hit1=(random.randint(1, 5))
hit2=(random.randint(1, 5))
hit3=(random.randint(1, 5))
hit4=(random.randint(1, 5))
hit5=(random.randint(1, 5))
hit6=(random.randint(1, 5))
hit7=(random.randint(1, 5))
hit8=(random.randint(1, 4))
hit9=(random.randint(1, 3))
hit10=(random.randint(1, 4))
hit11=(random.randint(1, 4))
hit12=(random.randint(1, 4))
aa=input('第二局')
bb=input('我方防守')
cc=input('敵方進攻')
dd=input('1變速球')
if dd=='1':
                                                            if hit7!=2:
                                                                    ee=input('一陣出局')
                                                                    ff=input('1變速球')
                                                                    if ff=='1':
                                                                         if hit8!=2:
                                                                                 gg=input('二陣出局')
                                                                                 hh=input('1變速球')
                                                                                 if hh=='1':
                                                                                     if hit9!=2:
                                                                                            ii=input('三陣出局')
                                                                                            jj=input('你贏了')
                                                                                     if hit9==2:
                                                                                          lost=input('敵方打出全壘打')  
                                                                                          lllost=input('你輸了')
                                                                         if hit8==2:
                                                                                          lost=input('敵方打出全壘打')  
                                                                                          lllost=input('你輸了')
                                                            if hit7==2:
                                                                                          lost=input('敵方打出全壘打')  
                                                                                          lllost=input('你輸了')

# %%
import random
hit=(random.randint(1, 10))
hit1=(random.randint(1, 5))
hit2=(random.randint(1, 5))
hit3=(random.randint(1, 10))
hit4=(random.randint(1, 5))
hit5=(random.randint(1, 5))
hit6=(random.randint(1, 5))
hit7=(random.randint(1, 5))
hit8=(random.randint(1, 4))
hit9=(random.randint(1, 3))
hit10=(random.randint(1, 4))
hit11=(random.randint(1, 4))
hit12=(random.randint(1, 4))
gid=(random.randint(1, 6))
gid1=(random.randint(1, 6))
tl=(random.randint(1, 10))
tlc=(random.randint(1, 10))
tlrc=(random.randint(1, 10))
a=input('第三個項目是.......籃球!')
b=input('跳球')
c=input('1跳球')
if c=='1':
    if hit<=5:
        d=input('我方進攻')
        d1=input('1三分球 2切入')
        if d1=='1':
            if hit1<=2:
                if hit2<=2:
                    e94=input('你被蓋了')
                    e=input('敵方進攻')
                    ea=input('對方切入')
                    eb=input('1抄球 2退後防守')
                    if eb=='1':
                         if tl<=7:
                              aaaaa=input('你被對方切入了')
                              if eb=='1':
                                   if tl<=7:
                                    aaaaa=input('你被對方切入了')
                              else:
                                   ssr=input('你抄到球了')
                         else:
                              ssr=input('你抄到球了')
                    else:
                         eb=input('1抄球 2退後防守')
                         if eb=='1':
                               if tl<=7:
                                    aaaaa=input('你被對方切入了')
                                    if eb=='1':
                                         if tl<=7:
                                             aaaaa=input('你被對方切入了')
                                         else:
                                             ssr=input('你抄到球了')
                                    else:
                                          ssr=input('你抄到球了')
                         else:
                             if tlc<=5:
                                   e=input ('對方投三分球')
                                   ee2=input('1蓋 2準備搶籃板 ')
                                   if ee2=='1':
                                         if hit2<=3:
                                             www=input('你蓋到他了')
                                             wc=input('我方進攻')
                                         else:
                                              if tlrc>3:
                                                 wwccc=input('對方進了    0:3')
                                              else:
                                                  yt=input('對方沒進')
                                                  搶=input('1搶籃板')
                                                  if 搶=='1':
                                                       if hit3<=5:
                                                           yy=input('你搶到了籃板')
                                                       else:
                                                           nn=input('對方搶到了籃板')
                                   else:
                                                       if hit2<=2:
                                                             wwccc=input('對方進了    0:3')
                                                       else:
                                                          搶=input('1搶籃板')
                                                          if 搶=='1':
                                                              if hit3<=7:
                                                                   yy=input('你搶到了籃板')
                                                              else:
                                                                   nn=input('對方搶到了籃板')
                

                else:
                    point=input('你進了3:0')
            else:
                no=input('你沒進')
                fu=input('1搶籃板')
                if fu=='1':
                    if hit3<=5:
                        yy=input('你搶到了籃板')
                    else:
                        nn=input('對方搶到了籃板')
        else:
            aaa=input('1急停跳投 2切入')
            if aaa=='1':
                if hit4>=3:
                    if hit12<=3:
                            e94=input('你被蓋了')
                            e=input('敵方進攻')
                else:
                    point=input('你進了2:0')
            else:
                aaaa=input('1上籃 2灌籃')
                if aaaa=='1':
                    if hit5<=4:
                        if gid<=4:
                            hhh=input('你被蓋了')
                            hhhh=input('敵方進攻')
                        else:
                            point=input('你進了2:0')
                    else:
                        no=input('你沒進')
                        fu=input('1搶籃板')
                        if fu=='1':
                            if hit3<=5:
                                   yy=input('你搶到了籃板')
                            else:
                                   nn=input('對方搶到了籃板')
                else:
                    if gid1<=4:
                        gg=input('你被蓋了')
                        eg=input('敵方進攻')
                    else:
                        point=input('你進了2:0')






                     
    else:
        e=input('敵方進攻')
        ea=input('對方切入')
        eb=input('1抄球 2退後防守')
        if eb=='1':
            if tl<=7:
                aaaaa=input('你被對方切入了')
                if eb=='1':
                    if tl<=7:
                        aaaaa=input('你被對方切入了')
                    else:
                        ssr=input('你抄到球了')
            else:
                ssr=input('你抄到球了')
        else:
            eb=input('1抄球 2退後防守')
            if eb=='1':
                if tl<=7:
                    aaaaa=input('你被對方切入了')
                    if eb=='1':
                        if tl<=7:
                            aaaaa=input('你被對方切入了')
                        else:
                            ssr=input('你抄到球了')
                else:
                    ssr=input('你抄到球了')
            else:
                if tlc<=5:
                    e=input ('對方投三分球')
                    ee2=input('1蓋 2準備搶籃板 ')
                    if ee2=='1':
                        if hit2<=3:
                            www=input('你蓋到他了')
                            wc=input('我方進攻')
                        else:
                            if tlrc>3:
                                wwccc=input('對方進了    0:3')
                            else:
                                yt=input('對方沒進')
                                搶=input('1搶籃板')
                                if 搶=='1':
                                    if hit3<=5:
                                          yy=input('你搶到了籃板')
                                    else:
                                          nn=input('對方搶到了籃板')
                    else:
                        if hit2<=2:
                            wwccc=input('對方進了    0:3')
                        else:
                                搶=input('1搶籃板')
                                if 搶=='1':
                                    if hit3<=7:
                                          yy=input('你搶到了籃板')
                                    else:
                                          nn=input('對方搶到了籃板')
                else:
                     input('對方切入')

# %%
import pyinputplus as pyip
import random as rm
成功抽獎=rm.randint(1 ,5)
攻擊=rm.randint(1 ,5)
a=input('你在大廳裡')
錢=0
大廳=input('1戰鬥 2袋子 3商店 4角色')
if 大廳=='1':
    搜尋=input('正在搜尋對手')
    對戰=input('你 vs @#$悟空')
    b=input('開始對戰')
    戰鬥=input('1小招 2二招 3大招')
    if 戰鬥=='1':
        血=10-攻擊
        血量=input(f'敵方血剩{血}')
        

elif 大廳=='2':
    袋子=input('你沒有物品')
    大廳=input('1戰鬥 3商店 4角色')
    if 大廳=='1':
        搜尋=input('正在搜尋對手')
    elif 大廳=='3':
        商店=input('你有免費抽獎一次的機會')
        抽獎=input('...')
        if 成功抽獎<=3:
            獲得=input('恭喜獲得100塊')
            錢=100
        else:
            可惜=input('貢箍')
    elif 大廳=='4':
        升級=input(' 1升級 耗100塊')
        if 升級=='1':
            if 錢==100:
                等級=input('你兩級了')
            else:    
                沒錢=input('你沒錢')
elif 大廳=='3':
    商店=input('你有免費抽獎一次的機會')
    抽獎=input('...')
    if 成功抽獎<=3:
        獲得=input('恭喜獲得100塊')
        錢=100
    else:
        可惜=input('貢箍')
    大廳=input('1戰鬥 2袋子 4角色')
    錢=100
    if 大廳=='1':
        搜尋=input('正在搜尋對手')
    elif 大廳=='2':
        袋子=input('你沒有物品')
    elif 大廳=='4':
        升級=input(' 1升級 耗100塊')
        if 升級=='1':
            if 錢==100:
                等級=input('你兩級了')
            else:
                沒錢=input('你沒錢')
elif 大廳=='4':
    升級=input(' 1升級 耗100塊')
    if 升級=='1':
        if 錢==100:
            等級=input('你兩級了')
        else:    
            沒錢=input('你沒錢')
            大廳=input('1戰鬥 2袋子 3商店')
            if 大廳=='1':
                搜尋=input('正在搜尋對手')
            elif 大廳=='2':
                袋子=input('你沒有物品')
            
            elif 大廳=='3':
                商店=input('你有免費抽獎一次的機會')
                抽獎=input('...')
                if 成功抽獎<=3:
                    獲得=input('恭喜獲得100塊')
                    錢=100
                else:
                    可惜=input('貢箍')
