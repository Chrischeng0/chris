# %%
##大老二##
from random import randint as rt
s=0
#我的牌
一 = rt(1,13)
二 = rt(1,13)
三 = rt(1,13)
四 = rt(1,13)
五 = rt(1,13)
#a的牌
一a = rt(1,13)
二a = rt(1,13)
三a = rt(1,13)
四a = rt(1,13)
五a = rt(1,13)
#b的牌
一b = rt(1,13)
二b = rt(1,13)
三b = rt(1,13)
四b = rt(1,13)
五b = rt(1,13)
#c的牌
一c = rt(1,13)
二c = rt(1,13)
三c = rt(1,13)
四c = rt(1,13)
五c = rt(1,13)
input('第一次的四個pass不要管它')
input(f'你的手排有{一}、{二}、{三}、{四}、{五}')
input(f'2號玩家先開始')
passme=input('1號pass')
passa=input('2號pass')
passb=input('3號pass')
passc=input('4號pass')


while(True):
    no=input('')
    if no=='yes':
        s=0
    if 一a < s:
        if 二a < s:
            if 三a < s:
                if 四a < s:
                    if 五a < s:
                        passa=input('2號pass')
                    else:
                        s=int(input(f'{五b}'))
                        input('換3號玩家')
                        五a = rt(1,13)
                else:
                    s=int(input(f'{四b}'))
                    input('換3號玩家')
                    四a = rt(1,13)
            else:
                s=int(input(f'{三b}'))
                input('換3號玩家')
                三a = rt(1,13)
        else:
            s=int(input(f'{二b}'))
            input('換3號玩家')
            二a = rt(1,13)
    else:
        s=int(input(f'{一b}'))
        input('換3號玩家')
        一a = rt(1,13)
    
    no=input('')
    if no=='yes':
        s=0
    if 一b < s:
        if 二b < s:
            if 三b < s:
                if 四b < s:
                    if 五b < s:
                        passb=input('3號pass')
                    else:
                        s=int(input(f'{五b}'))
                        input('換4號玩家')
                        五b = rt(1,13)
                else:
                    s=int(input(f'{四b}'))
                    input('換4號玩家')
                    四b = rt(1,13)
            else:
                s=int(input(f'{三b}'))
                input('換4號玩家')
                三b = rt(1,13)
        else:
            s=int(input(f'{二b}'))
            input('換4號玩家')
            二b = rt(1,13)
    else:
        s=int(input(f'{一b}'))
        input('換4號玩家')
        一b = rt(1,13)
    
    no=input('')
    if no=='yes':
        s=0
    if 一c < s:
        if 二c < s:
            if 三c < s:
                if 四c < s:
                    if 五c < s:
                        passc=input('4號pass')
                    else:
                        s=int(input(f'{五c}'))
                        input('換1號玩家')
                        五c = rt(1,13)
                else:
                    s=int(input(f'{四c}'))
                    input('換1號玩家')
                    四c = rt(1,13)
            else:
                s=int(input(f'{三c}'))
                input('換1號玩家')
                三c = rt(1,13)
        else:
            s=int(input(f'{二c}'))
            input('換1號玩家')
            二c = rt(1,13)
    else:
        s=int(input(f'{一c}'))
        input('換1號玩家')
        一c = rt(1,13)
    while(True):
        no=input('')
        if no=='yes':
            s=0
        you=int(input(f'你要出{一}還是{二}還是{三}還是{四}還是{五}'))
        if you==一:
            if 一<s:
               continue
            else:
                s=一
                一 = rt(1,13)

                break
        if you==二:
            if 二<s:
               continue
            else:
                s=二
                二 = rt(1,13)

                break
        if you==三:
            if 三<s:
               continue
            else:
                s=三
                三 = rt(1,13)

                break
        if you==四:
            if 四<s:
               continue
            else:
                s=四
                四 = rt(1,13)

                break
        if you==五:
            if 五<s:
               continue
            else:
                s=五
                五 = rt(1,13)

                break
        if you==44:
            break
