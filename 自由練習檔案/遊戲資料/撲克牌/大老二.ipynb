# %%
from random import randint as rt
#我的牌
一 = rt(1,13)
二 = rt(1,13)
三 = rt(1,13)
四 = rt(1,13)
五 = rt(1,13)
#a的牌
一a = rt(1,13)
二a = rt(1,13)
三a = rt(1,13)
四a = rt(1,13)
五a = rt(1,13)
#b的牌
一b = rt(1,13)
二b = rt(1,13)
三b = rt(1,13)
四b = rt(1,13)
五b = rt(1,13)
#c的牌
一c = rt(1,13)
二c = rt(1,13)
三c = rt(1,13)
四c = rt(1,13)
五c = rt(1,13)

input(f'你的手排有{一}、{二}、{三}、{四}、{五}')
input(f'2號玩家先開始')
while(True):
    a=rt(1,5)
    if a==1:
        s=int(input(f'{一a}'))
        input('換3號玩家')
        一a = rt(1,13)
    if a==2:
        s=int(input(f'{二a}'))
        input('換3號玩家')
        二a = rt(1,13)
    if a==3:
        s=int(input(f'{三a}'))
        input('換3號玩家')
        三a = rt(1,13)
    if a==4:
        s=int(input(f'{四a}'))
        input('換3號玩家')
        四a = rt(1,13)
    if a==5:
        s=int(input(f'{五a}'))
        input('換3號玩家')
        五a = rt(1,13)
    
    if 一b <= s:
        if 二b <= s:
            if 三b <= s:
                if 四b <= s:
                    if 五b <= s:
                        input('3號pass')
                    else:
                        s=int(input(f'{五b}'))
                        input('換4號玩家')
                        五b = rt(1,13)
                else:
                    s=int(input(f'{四b}'))
                    input('換4號玩家')
                    四b = rt(1,13)
            else:
                s=int(input(f'{三b}'))
                input('換4號玩家')
                三b = rt(1,13)
        else:
            s=int(input(f'{二b}'))
            input('換4號玩家')
            二b = rt(1,13)
    else:
        s=int(input(f'{一b}'))
        input('換4號玩家')
        一b = rt(1,13)

    if 一c <= s:
        if 二c <= s:
            if 三c <= s:
                if 四c <= s:
                    if 五c <= s:
                        input('4號pass')
                    else:
                        s=input(f'{五c}')
                        input('換1號玩家')
                        五c = rt(1,13)
                else:
                    s=input(f'{四c}')
                    input('換1號玩家')
                    四c = rt(1,13)
            else:
                s=input(f'{三c}')
                input('換1號玩家')
                三c = rt(1,13)
        else:
            s=input(f'{二c}')
            input('換1號玩家')
            二c = rt(1,13)
    else:
        s=input(f'{一c}')
        input('換1號玩家')
        一c = rt(1,13)
