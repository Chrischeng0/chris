# %%
##貪心往下挖##
import random as rm
def 貪心往下挖():
    input('貪心往下挖 開始!')
    input('有四個孔,四個孔都是直直往下的,每個孔都有隨機個鑽石,挖到一個鑽石就是50塊錢,最深處有岩漿,隨時可以喊停')
    孔=input('1=一孔 2=二孔 3=三孔 4=四孔')
    if 孔==1:
        while(True):
            一孔=rm.randint(1,20)
            一=一孔
            挖=input('1挖 2停')
            if 挖=='1':
                一-=1
                if 一<=0:
                    input('你太貪心了,你死了')
                    錢=0
                    break
                else:
                    continue
            else:
                break
    elif 孔==2:
        while(True):
            二孔=rm.randint(1,20)
            二=二孔
            挖=input('1挖 2停')
            if 挖=='1':
                二-=1
                if 二<=0:
                    input('你太貪心了,你死了')
                    錢=0
                    break
                else:
                    continue
            else:
                break
    elif 孔==3:
        while(True):
            三孔=rm.randint(1,20)
            三=三孔
            挖=input('1挖 2停')
            if 挖=='1':
                三-=1
                if 三<=0:
                    input('你太貪心了,你死了')
                    錢=0 
                    break
                else:
                    continue
            else:
                break
    else:
        while(True):
            四孔=rm.randint(1,20)
            四=四孔
            挖=input('1挖 2停')
            if 挖=='1':
                四-=1
                if 四<=0:
                    input('你太貪心了,你死了')
                    錢=0
                    break
                else:
                    continue
            else:
                break
    錢=300
貪心往下挖()
